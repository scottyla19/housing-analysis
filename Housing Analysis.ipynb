# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %matplotlib inline

# %%
# df = pd.read_csv('Zip_MedianValuePerSqft_AllHomes.csv')
df= pd.read_csv('http://files.zillowstatic.com/research/public/Zip/Zip_MedianValuePerSqft_AllHomes.csv')
df.tail()
# Out:
#        RegionID  RegionName             City State      Metro    CountyName  \
# 14824     73940       36564         Fairhope    AL     Daphne       Baldwin
# 14825     59107        3293        Woodstock    NH  Claremont       Grafton
# 14826     82396       55713             Buhl    MN     Duluth   Saint Louis
# 14827     66881       21405        Annapolis    MD  Baltimore  Anne Arundel
# 14828     94815       85220  Apache Junction    AZ    Phoenix         Pinal
#
#        SizeRank  1996-04  1996-05  1996-06   ...     2017-03  2017-04  \
# 14824     14825      NaN      NaN      NaN   ...         242      245
# 14825     14826     58.0     59.0     61.0   ...         128      128
# 14826     14827      NaN      NaN      NaN   ...          74       74
# 14827     14828    146.0    149.0    151.0   ...         456      456
# 14828     14829      NaN      NaN      NaN   ...         119      119
#
#        2017-05  2017-06  2017-07  2017-08  2017-09  2017-10  2017-11  2017-12
# ...

# %%
waco = df[df["Metro"] == "Waco"]

waco.head(10)
# Out:
#        RegionID  RegionName          City State Metro CountyName  SizeRank  \
# 3607      91560       76710          Waco    TX  Waco   McLennan      3608
# 4017      91562       76712       Woodway    TX  Waco   McLennan      4018
# 6971      91515       76643        Hewitt    TX  Waco   McLennan      6972
# 9423      91525       76655        Lorena    TX  Waco   McLennan      9424
# 9672      91529       76661        Marlin    TX  Waco      Falls      9673
# 10955     91474       76557         Moody    TX  Waco   McLennan     10956
# 10987     91505       76633  China Spring    TX  Waco   McLennan     10988
# 12889     91510       76638      Crawford    TX  Waco   McLennan     12890
# 13429     91497       76624     Hallsburg    TX  Waco   McLennan     13430
#
#        1996-04  1996-05  1996-06   ...     2017-03  2017-04  2017-05  2017-06  \
# 3607      44.0     44.0     45.0   ...          80       81       82       82
# ...

# %%
plot_table = pd.melt(waco.reset_index(), value_vars=waco.columns[7:], id_vars=["City"])
dfYrM = pd.DataFrame(plot_table['variable'].str.split('-').tolist(), columns=['Year','Month'])
plot_table["Year"] = dfYrM["Year"]
plot_table["Month"] = dfYrM["Month"]
plot_table
# Out:
#               City variable  value  Year Month
# 0             Waco  1996-04   44.0  1996    04
# 1          Woodway  1996-04   51.0  1996    04
# 2           Hewitt  1996-04   49.0  1996    04
# 3           Lorena  1996-04   52.0  1996    04
# 4           Marlin  1996-04   35.0  1996    04
# 5            Moody  1996-04   41.0  1996    04
# 6     China Spring  1996-04   52.0  1996    04
# 7         Crawford  1996-04   50.0  1996    04
# 8        Hallsburg  1996-04   47.0  1996    04
# 9             Waco  1996-05   44.0  1996    05
# 10         Woodway  1996-05   51.0  1996    05
# 11          Hewitt  1996-05   49.0  1996    05
# 12          Lorena  1996-05   52.0  1996    05
# 13          Marlin  1996-05   36.0  1996    05
# 14           Moody  1996-05   41.0  1996    05
# 15    China Spring  1996-05   52.0  1996    05
# 16        Crawford  1996-05   50.0  1996    05
# 17       Hallsburg  1996-05   47.0  1996    05
# 18            Waco  1996-06   45.0  1996    06
# ...

# %% [markdown]
# ## Time Series

# %%
fig, ax = plt.subplots(figsize=(15,10))

g = sns.pointplot(data = plot_table, x = 'variable', y = "value", hue="City", markers=".", scale = .5)
g.set_xticks([])
g.set_xlabel("Time")
g.set_ylabel("Median Price per sq ft.")
# Out:
# Text(0,0.5,'Median Price per sq ft.')

# %%
g= sns.FacetGrid(plot_table, col='Month', row="City")
g = g.map(plt.plot, "Year", "value")
g.set(xticks=plot_table.Year[2::8])
# g.set_xticklabels([])


# for ax in g.axes.flat:
#     for label in ax.xaxis.get_ticklabels():
#         label.set_visible(False)
