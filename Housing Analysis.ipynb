# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# df = pd.read_csv('Zip_MedianValuePerSqft_AllHomes.csv')
df= pd.read_csv('http://files.zillowstatic.com/research/public/Zip/Zip_MedianValuePerSqft_AllHomes.csv')
df.tail()
# Out:
#        RegionID  RegionName             City State      Metro    CountyName  \
# 14866     73940       36564         Fairhope    AL     Daphne       Baldwin
# 14867     59107        3293        Woodstock    NH  Claremont       Grafton
# 14868     82396       55713             Buhl    MN     Duluth   Saint Louis
# 14869     66881       21405        Annapolis    MD  Baltimore  Anne Arundel
# 14870     94815       85220  Apache Junction    AZ    Phoenix         Pinal
#
#        SizeRank  1996-04  1996-05  1996-06   ...     2017-02  2017-03  \
# 14866     14867      NaN      NaN      NaN   ...         238      243
# 14867     14868     58.0     59.0     61.0   ...         128      128
# 14868     14869      NaN      NaN      NaN   ...          73       74
# 14869     14870    146.0    149.0    151.0   ...         461      456
# 14870     14871      NaN      NaN      NaN   ...         119      119
#
#        2017-04  2017-05  2017-06  2017-07  2017-08  2017-09  2017-10  2017-11
# 14866      246      245      245      246      243      242      243      242
# 14867      128      129      129      129      129      130      130      130
# 14868       74       73       73       74       76       77       78       77
# 14869      456      455      454      454      456      454      451      449
# 14870      119      120      121      123      124      125      126      126
#
# [5 rows x 267 columns]

# %%
waco = df[df["Metro"] == "Waco"]
waco.head(10)
# Out:
#        RegionID  RegionName          City State Metro CountyName  SizeRank  \
# 3612      91560       76710          Waco    TX  Waco   McLennan      3613
# 4024      91562       76712       Woodway    TX  Waco   McLennan      4025
# 6997      91515       76643        Hewitt    TX  Waco   McLennan      6998
# 9472      91525       76655        Lorena    TX  Waco   McLennan      9473
# 9723      91529       76661        Marlin    TX  Waco      Falls      9724
# 11002     91474       76557         Moody    TX  Waco   McLennan     11003
# 11034     91505       76633  China Spring    TX  Waco   McLennan     11035
# 12940     91510       76638      Crawford    TX  Waco   McLennan     12941
# 13475     91497       76624     Hallsburg    TX  Waco   McLennan     13476
#
#        1996-04  1996-05  1996-06   ...     2017-02  2017-03  2017-04  2017-05  \
# 3612      44.0     44.0     45.0   ...          79       80       81       82
# 4024      51.0     51.0     52.0   ...          95       96       96       97
# 6997      49.0     49.0     50.0   ...          92       93       93       94
# 9472      52.0     52.0     52.0   ...         100      102      102      103
# 9723      35.0     36.0     36.0   ...          40       41       41       41
# 11002     41.0     41.0     41.0   ...          85       87       87       88
# 11034     52.0     52.0     52.0   ...         107      109      110      111
# 12940     50.0     50.0     50.0   ...         112      113      114      116
# 13475     47.0     47.0     47.0   ...          95       97       98       99
#
#        2017-06  2017-07  2017-08  2017-09  2017-10  2017-11
# 3612        82       82       82       82       84       85
# 4024        97       97       96       97       97       98
# 6997        95       95       94       94       96       96
# 9472       103      103      102      102      103      103
# 9723        42       42       43       43       43       42
# 11002       88       88       87       88       89       89
# 11034      112      112      111      110      110      110
# 12940      116      116      115      114      115      115
# 13475       99       99       99       99      100      100
#
# [9 rows x 267 columns]

# %%
dates = waco.columns[7:]
plot_table = pd.melt(waco.reset_index(), value_vars=waco.columns[7:], id_vars=["City"])
plot_table
fig, ax = plt.subplots(figsize=(15,10))
ax.set_xticks([])
ax.set_xlabel("Time")
ax.set_ylabel("Median Price per sq ft.")

g = sns.pointplot(data = plot_table, x = 'variable', y = "value", hue="City", markers=".")
